# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#q1
file="COVID-19 Daily.xlsx"
#For Pakistan
df=pd.read_excel(file,sheet_name=["PK"])
df
# Out:
# {'PK':           Date  Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  0   2020-02-26          NaN          0.0               NaN           NaN
#  1   2020-02-27          NaN          NaN               NaN           NaN
#  2   2020-02-28          NaN          NaN               NaN           NaN
#  3   2020-02-29          NaN          0.0               NaN           NaN
#  4   2020-03-01          NaN          NaN               NaN           NaN
#  ..         ...          ...          ...               ...           ...
#  183 2020-08-27      23483.0        415.0             376.0           NaN
#  184 2020-08-28      22434.0        319.0             403.0           NaN
#  185 2020-08-29      21434.0        264.0             207.0           NaN
#  186 2020-08-30      18017.0        213.0             135.0           NaN
#  187 2020-08-31      20882.0        300.0             288.0           NaN
#
#  [188 rows x 5 columns]}

# %%
# Access a specific sheet
df_pak = df['PK']

# %%
null_values = df_pak.isnull().sum()
null_values
# Out:
# Date                 0
# Daily Tests         13
# Daily Cases         11
# Daily Recoveries    15
# Daily Deaths        57
# dtype: int64

# %%
# Replace all null values with 0
df_filled = df_pak.fillna(0)
df_filled.isnull().sum()
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# dtype: int64

# %%
#column info
column_info = df_filled.info()
column_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       188 non-null    float64
#  2   Daily Cases       188 non-null    float64
#  3   Daily Recoveries  188 non-null    float64
#  4   Daily Deaths      188 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.5 KB

# %%
#descriptive stats
descriptive_stats = df_filled.describe()
descriptive_stats
# Out:
#                       Date   Daily Tests  Daily Cases  Daily Recoveries  \
# count                  188    188.000000   188.000000        188.000000
# mean   2020-05-29 12:00:00  13895.090426  1575.138298       1463.994681
# min    2020-02-26 00:00:00      0.000000     0.000000          0.000000
# 25%    2020-04-12 18:00:00   3139.750000   295.250000         82.500000
# 50%    2020-05-29 12:00:00  14286.500000   841.500000        574.000000
# 75%    2020-07-15 06:00:00  22690.500000  2294.750000       1833.500000
# max    2020-08-31 00:00:00  31681.000000  6825.000000      16813.000000
# std                    NaN   9705.297440  1677.812930       2427.451529
#
#        Daily Deaths
# count    188.000000
# mean      29.622340
# min        0.000000
# 25%        0.000000
# 50%       11.500000
# 75%       50.000000
# max      153.000000
# std       37.487837

# %%
#q2

total_tests=df_filled['Daily Tests'].sum()
total_tests
# Out:
# 2612277.0

# %%
#
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
average_tests = df_filled['Daily Tests'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Tests'], color='green')
plt.scatter(df_filled[df_filled['Daily Tests'] > average_tests]['Date'], df_filled[df_filled['Daily Tests'] > average_tests]['Daily Tests'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#daily cases
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Cases'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Cases'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()


average_cases = df_filled['Daily Cases'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Cases'], color='green')
plt.scatter(df_filled[df_filled['Daily Cases'] > average_cases]['Date'], df_filled[df_filled['Daily Cases'] > average_cases]['Daily Cases'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_cases = df_filled['Daily Cases'].mean()

plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Cases'], color='red')
plt.bar(df_filled[df_filled['Daily Cases'] > average_cases]['Date'], df_filled[df_filled['Daily Cases'] > average_cases]['Daily Cases'], color='blue')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#daily recovery
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Recoveries'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Recoveries'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_recoveries = df_filled['Daily Recoveries'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Recoveries'], color='green')
plt.scatter(df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Date'], df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Daily Recoveries'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_recoveries = df_filled['Daily Recoveries'].mean()
plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Recoveries'], color='green')
plt.bar(df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Date'], df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Daily Recoveries'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#q3

# Convert Date column to datetime
df_filled['Date'] = pd.to_datetime(df_filled['Date'])

# Weekly Stats
weekly_df = df_filled.resample('W', on='Date').sum()

# Monthly Stats
monthly_df = df_filled.resample('M', on='Date').sum()

# Save weekly and monthly data
weekly_df.to_excel('Weekly_Stats.xlsx')
monthly_df.to_excel('Monthly_Stats.xlsx')

weekly_df.head(), monthly_df.head()
# Out:
# C:\Users\faraz 1\AppData\Local\Temp\ipykernel_10924\3280754615.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df_filled.resample('M', on='Date').sum()
# (            Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  Date
#  2020-03-01          0.0          0.0               0.0           0.0
#  2020-03-08          0.0          0.0               0.0           0.0
#  2020-03-15       1430.0         35.0               3.0           0.0
#  2020-03-22       7315.0        750.0               3.0           6.0
#  2020-03-29      10318.0        822.0              26.0          12.0,
#              Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  Date
#  2020-02-29          0.0          0.0               0.0           0.0
#  2020-03-31      22763.0       2021.0              82.0          26.0
#  2020-04-30     143163.0      14778.0            4233.0         359.0
#  2020-05-31     365062.0      55638.0           21768.0        1158.0
#  2020-06-30     745419.0     141010.0           74519.0        2852.0)

# %%
# Weekly Max/Min
weekly_max_tests = weekly_df['Daily Tests'].max()
weekly_min_tests = weekly_df['Daily Tests'].min()

# Monthly Max/Min
monthly_max_tests = monthly_df['Daily Tests'].max()
monthly_min_tests = monthly_df['Daily Tests'].min()

weekly_max_tests, weekly_min_tests, monthly_max_tests, monthly_min_tests
# Out:
# (204512.0, 0.0, 745419.0, 0.0)

# %%
#q4

# Assuming 'data_filled' is your DataFrame
population_million = 220

# Convert the 'Date' column to datetime format if not already
df_filled['Date'] = pd.to_datetime(df_filled['Date'])

# Calculate Per Thousand and Per Million stats
df_filled['Tests per Thousand'] = (df_filled['Daily Tests'] / population_million) / 1000
df_filled['Cases per Thousand'] = (df_filled['Daily Cases'] / population_million) / 1000
df_filled['Recoveries per Thousand'] = (df_filled['Daily Recoveries'] / population_million) / 1000
df_filled['Deaths per Thousand'] = (df_filled['Daily Deaths'] / population_million) / 1000

df_filled['Tests per Million'] = (df_filled['Daily Tests'] / population_million) * 1
df_filled['Cases per Million'] = (df_filled['Daily Cases'] / population_million) * 1
df_filled['Recoveries per Million'] = (df_filled['Daily Recoveries'] / population_million) * 1
df_filled['Deaths per Million'] = (df_filled['Daily Deaths'] / population_million) * 1

# Group by Month and aggregate the data
monthly_data = df_filled.groupby(df_filled['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]

# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_1b37c thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_1b37c_row0_col1, #T_1b37c_row0_col2, #T_1b37c_row0_col3, #T_1b37c_row0_col4, #T_1b37c_row0_col5, #T_1b37c_row0_col6, #T_1b37c_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1b37c_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1b37c_row1_col1, #T_1b37c_row1_col3, #T_1b37c_row1_col5 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_1b37c_row1_col2, #T_1b37c_row1_col4, #T_1b37c_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_1b37c_row1_col7 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_1b37c_row2_col1, #T_1b37c_row2_col3, #T_1b37c_row2_col5 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_1b37c_row2_col2, #T_1b37c_row2_col4, #T_1b37c_row2_col6 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_1b37c_row2_col7 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_1b37c_row3_col1, #T_1b37c_row3_col3, #T_1b37c_row3_col5 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_1b37c_row3_col2, #T_1b37c_row3_col4, #T_1b37c_row3_col6 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_1b37c_row3_col7 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_1b37c_row4_col1, #T_1b37c_row4_col2, #T_1b37c_row4_col3, #T_1b37c_row4_col4, #T_1b37c_row4_col5, #T_1b37c_row4_col6, #T_1b37c_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1b37c_row5_col1, #T_1b37c_row5_col3, #T_1b37c_row5_col5 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_1b37c_row5_col2, #T_1b37c_row5_col4, #T_1b37c_row5_col6 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_1b37c_row5_col7 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_1b37c_row6_col1, #T_1b37c_row6_col3, #T_1b37c_row6_col5 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_1b37c_row6_col2, #T_1b37c_row6_col4, #T_1b37c_row6_col6 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# </style>
# <table id="T_1b37c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b37c_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_1b37c_level0_col1" class="col_heading level0 col1" >Daily Tests</th>
#       <th id="T_1b37c_level0_col2" class="col_heading level0 col2" >Daily Cases</th>
#       <th id="T_1b37c_level0_col3" class="col_heading level0 col3" >Tests per Thousand</th>
#       <th id="T_1b37c_level0_col4" class="col_heading level0 col4" >Cases per Thousand</th>
#       <th id="T_1b37c_level0_col5" class="col_heading level0 col5" >Tests per Million</th>
#       <th id="T_1b37c_level0_col6" class="col_heading level0 col6" >Cases per Million</th>
#       <th id="T_1b37c_level0_col7" class="col_heading level0 col7" >Positive Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b37c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b37c_row0_col0" class="data row0 col0" >February</td>
#       <td id="T_1b37c_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_1b37c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_1b37c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_1b37c_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_1b37c_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_1b37c_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_1b37c_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b37c_row1_col0" class="data row1 col0" >March</td>
#       <td id="T_1b37c_row1_col1" class="data row1 col1" >22763.000000</td>
#       <td id="T_1b37c_row1_col2" class="data row1 col2" >2021.000000</td>
#       <td id="T_1b37c_row1_col3" class="data row1 col3" >0.103468</td>
#       <td id="T_1b37c_row1_col4" class="data row1 col4" >0.009186</td>
#       <td id="T_1b37c_row1_col5" class="data row1 col5" >103.468182</td>
#       <td id="T_1b37c_row1_col6" class="data row1 col6" >9.186364</td>
#       <td id="T_1b37c_row1_col7" class="data row1 col7" >8.878443</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b37c_row2_col0" class="data row2 col0" >April</td>
#       <td id="T_1b37c_row2_col1" class="data row2 col1" >143163.000000</td>
#       <td id="T_1b37c_row2_col2" class="data row2 col2" >14778.000000</td>
#       <td id="T_1b37c_row2_col3" class="data row2 col3" >0.650741</td>
#       <td id="T_1b37c_row2_col4" class="data row2 col4" >0.067173</td>
#       <td id="T_1b37c_row2_col5" class="data row2 col5" >650.740909</td>
#       <td id="T_1b37c_row2_col6" class="data row2 col6" >67.172727</td>
#       <td id="T_1b37c_row2_col7" class="data row2 col7" >10.322500</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b37c_row3_col0" class="data row3 col0" >May</td>
#       <td id="T_1b37c_row3_col1" class="data row3 col1" >365062.000000</td>
#       <td id="T_1b37c_row3_col2" class="data row3 col2" >55638.000000</td>
#       <td id="T_1b37c_row3_col3" class="data row3 col3" >1.659373</td>
#       <td id="T_1b37c_row3_col4" class="data row3 col4" >0.252900</td>
#       <td id="T_1b37c_row3_col5" class="data row3 col5" >1659.372727</td>
#       <td id="T_1b37c_row3_col6" class="data row3 col6" >252.900000</td>
#       <td id="T_1b37c_row3_col7" class="data row3 col7" >15.240699</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b37c_row4_col0" class="data row4 col0" >June</td>
#       <td id="T_1b37c_row4_col1" class="data row4 col1" >745419.000000</td>
#       <td id="T_1b37c_row4_col2" class="data row4 col2" >141010.000000</td>
#       <td id="T_1b37c_row4_col3" class="data row4 col3" >3.388268</td>
#       <td id="T_1b37c_row4_col4" class="data row4 col4" >0.640955</td>
#       <td id="T_1b37c_row4_col5" class="data row4 col5" >3388.268182</td>
#       <td id="T_1b37c_row4_col6" class="data row4 col6" >640.954545</td>
#       <td id="T_1b37c_row4_col7" class="data row4 col7" >18.916878</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b37c_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_1b37c_row5_col1" class="data row5 col1" >690360.000000</td>
#       <td id="T_1b37c_row5_col2" class="data row5 col2" >65676.000000</td>
#       <td id="T_1b37c_row5_col3" class="data row5 col3" >3.138000</td>
#       <td id="T_1b37c_row5_col4" class="data row5 col4" >0.298527</td>
#       <td id="T_1b37c_row5_col5" class="data row5 col5" >3138.000000</td>
#       <td id="T_1b37c_row5_col6" class="data row5 col6" >298.527273</td>
#       <td id="T_1b37c_row5_col7" class="data row5 col7" >9.513297</td>
#     </tr>
#     <tr>
#       <th id="T_1b37c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b37c_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_1b37c_row6_col1" class="data row6 col1" >645510.000000</td>
#       <td id="T_1b37c_row6_col2" class="data row6 col2" >17003.000000</td>
#       <td id="T_1b37c_row6_col3" class="data row6 col3" >2.934136</td>
#       <td id="T_1b37c_row6_col4" class="data row6 col4" >0.077286</td>
#       <td id="T_1b37c_row6_col5" class="data row6 col5" >2934.136364</td>
#       <td id="T_1b37c_row6_col6" class="data row6 col6" >77.286364</td>
#       <td id="T_1b37c_row6_col7" class="data row6 col7" >2.634041</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = df_filled[['Daily Tests']]  # Feature (you can choose other features as well)
cases = df_filled['Daily Cases']  # Target for cases
deaths = df_filled['Daily Deaths']  # Target for deaths

# Drop rows with missing values in X, y_cases, or y_deaths
df_clean = df_filled.dropna(subset=['Daily Tests', 'Daily Cases', 'Daily Deaths'])
X_clean = df_clean[['Daily Tests']]
cases_clean = df_clean['Daily Cases']
deaths_clean = df_clean['Daily Deaths']

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X_clean, cases_clean, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X_clean, deaths_clean, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
model = LinearRegression()
model.fit(X_train, y_cases_train)
cases_predictions = model.predict(X_test)


# Display the results
print(f"Cases: {cases_predictions}")
# Out:
# Cases: [ 2.71885005e+03  2.36556569e+03  2.61966228e+01  4.77708487e-01
#   1.08675113e+03  3.42763995e+03  3.01505910e+02  1.35867019e+03
#  -1.06812293e-01  2.11655984e+03  7.20724214e+02  2.66343748e+03
#   2.93556428e+02  2.37094328e+03  6.32578480e+02  9.92526377e+02
#   3.34685918e+03  1.26257498e+03  1.79574876e+02  2.52619200e+03
#   1.16344025e+03  2.03250575e+03  2.80395627e+03  4.08096423e+01
#   7.23646818e+02  2.89104987e+03 -2.64102474e+01  2.78186139e+03
#   1.43100779e+02  1.90811973e+03  2.10440180e+03 -2.64102474e+01
#   2.26608025e+03  1.57517669e+03  1.72726900e+03  3.26058391e+03
#   1.04489944e+03  2.53975288e+03]

# %%
# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

print(f" Deaths: {deaths_predictions}")
# Out:
#  Deaths: [1.81500000e+01 4.36000000e+00 8.00000000e-02 0.00000000e+00
#  2.72200000e+01 1.02850000e+02 4.61000000e+00 2.00100000e+01
#  0.00000000e+00 8.20000000e-01 1.74600000e+01 5.18500000e+01
#  4.48000000e+00 4.36000000e+00 1.63600000e+01 3.16100000e+01
#  1.23480000e+02 2.74000000e+01 1.41228571e+00 4.69100000e+01
#  2.89900000e+01 2.09300000e+01 1.68200000e+01 4.80000000e-01
#  1.75900000e+01 8.95000000e+01 0.00000000e+00 3.93300000e+01
#  9.50000000e-01 5.03800000e+01 9.88000000e+00 0.00000000e+00
#  8.56000000e+00 3.31000000e+01 6.66800000e+01 1.23860000e+02
#  3.17900000e+01 1.78500000e+01]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#q1
file="COVID-19 Daily.xlsx"
#For Pakistan
df=pd.read_excel(file,sheet_name=["Punjab"])
df
# Out:
# {'Punjab':           Date  Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  0   2020-02-26          NaN          0.0               NaN           NaN
#  1   2020-02-27          NaN          NaN               NaN           NaN
#  2   2020-02-28          NaN          NaN               NaN           NaN
#  3   2020-02-29          NaN          0.0               NaN           NaN
#  4   2020-03-01          NaN          NaN               NaN           NaN
#  ..         ...          ...          ...               ...           ...
#  183 2020-08-27       9939.0         96.0              28.0           2.0
#  184 2020-08-28       9603.0         63.0              28.0           0.0
#  185 2020-08-29       7444.0         42.0              22.0           1.0
#  186 2020-08-30       5920.0         28.0              10.0           2.0
#  187 2020-08-31       8805.0         63.0              18.0           1.0
#
#  [188 rows x 5 columns]}

# %%
# Access a specific sheet
df_pak = df['Punjab']

# %%
null_values = df_pak.isnull().sum()
null_values
# Out:
# Date                 0
# Daily Tests         13
# Daily Cases         11
# Daily Recoveries    13
# Daily Deaths        13
# dtype: int64

# %%
# Replace all null values with 0
df_filled = df_pak.fillna(0)
df_filled.isnull().sum()
# Out:
# Date                0
# Daily Tests         0
# Daily Cases         0
# Daily Recoveries    0
# Daily Deaths        0
# dtype: int64

# %%
#column info
column_info = df_filled.info()
column_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              188 non-null    datetime64[ns]
#  1   Daily Tests       188 non-null    float64
#  2   Daily Cases       188 non-null    float64
#  3   Daily Recoveries  188 non-null    float64
#  4   Daily Deaths      188 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.5 KB

# %%
#descriptive stats
descriptive_stats = df_filled.describe()
descriptive_stats
# Out:
#                       Date   Daily Tests  Daily Cases  Daily Recoveries  \
# count                  188    188.000000   188.000000        188.000000
# mean   2020-05-29 12:00:00   5011.627660   515.063830        492.015957
# min    2020-02-26 00:00:00      0.000000     0.000000          0.000000
# 25%    2020-04-12 18:00:00   2056.500000    75.000000          4.750000
# 50%    2020-05-29 12:00:00   5431.500000   255.500000         56.500000
# 75%    2020-07-15 06:00:00   7696.750000   706.750000        331.250000
# max    2020-08-31 00:00:00  11739.000000  2705.000000      12802.000000
# std                    NaN   3300.102876   627.450785       1480.617321
#
#        Daily Deaths
# count    188.000000
# mean      11.696809
# min        0.000000
# 25%        1.000000
# 50%        4.500000
# 75%       15.000000
# max       86.000000
# std       16.831934

# %%
#q2

total_tests=df_filled['Daily Tests'].sum()
total_tests
# Out:
# 942186.0

# %%
#
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Tests'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

#
average_tests = df_filled['Daily Tests'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Tests'], color='green')
plt.scatter(df_filled[df_filled['Daily Tests'] > average_tests]['Date'], df_filled[df_filled['Daily Tests'] > average_tests]['Daily Tests'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Testing')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#daily cases
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Cases'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Cases'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()


average_cases = df_filled['Daily Cases'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Cases'], color='green')
plt.scatter(df_filled[df_filled['Daily Cases'] > average_cases]['Date'], df_filled[df_filled['Daily Cases'] > average_cases]['Daily Cases'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_cases = df_filled['Daily Cases'].mean()

plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Cases'], color='red')
plt.bar(df_filled[df_filled['Daily Cases'] > average_cases]['Date'], df_filled[df_filled['Daily Cases'] > average_cases]['Daily Cases'], color='blue')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Cases')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#daily recovery
plt.figure(figsize=(10, 5))
plt.plot(df_filled['Date'], df_filled['Daily Recoveries'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Recoveries'], label='Daily Tests', color='blue')
plt.title('Daily Testing Trend Line')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_recoveries = df_filled['Daily Recoveries'].mean()

plt.figure(figsize=(10, 5))
plt.scatter(df_filled['Date'], df_filled['Daily Recoveries'], color='green')
plt.scatter(df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Date'], df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Daily Recoveries'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

average_recoveries = df_filled['Daily Recoveries'].mean()
plt.figure(figsize=(10, 5))
plt.bar(df_filled['Date'], df_filled['Daily Recoveries'], color='green')
plt.bar(df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Date'], df_filled[df_filled['Daily Recoveries'] > average_recoveries]['Daily Recoveries'], color='red')
plt.title('Above-Average (Red) and Below-Average (Green) Daily Recoveries')
plt.xlabel('Date')
plt.ylabel('Number of Tests')
plt.show()

# %%
#q3

# Convert Date column to datetime
df_filled['Date'] = pd.to_datetime(df_filled['Date'])

# Weekly Stats
weekly_df = df_filled.resample('W', on='Date').sum()

# Monthly Stats
monthly_df = df_filled.resample('M', on='Date').sum()

# Save weekly and monthly data
weekly_df.to_excel('Weekly_Stats_punjab.xlsx')
monthly_df.to_excel('Monthly_Stats_punjab.xlsx')

weekly_df.head(), monthly_df.head()
# Out:
# C:\Users\faraz 1\AppData\Local\Temp\ipykernel_24140\3019386619.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df_filled.resample('M', on='Date').sum()
# (            Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  Date
#  2020-03-01          0.0          0.0               0.0           0.0
#  2020-03-08          0.0          0.0               0.0           0.0
#  2020-03-15          0.0          1.0               0.0           0.0
#  2020-03-22       1270.0        224.0               0.0           0.0
#  2020-03-29       4384.0        368.0               5.0           6.0,
#              Daily Tests  Daily Cases  Daily Recoveries  Daily Deaths
#  Date
#  2020-02-29          0.0          0.0               0.0           0.0
#  2020-03-31      10310.0        708.0               5.0           9.0
#  2020-04-30      58931.0       5632.0            1916.0          97.0
#  2020-05-31     153954.0      19900.0            5100.0         391.0
#  2020-06-30     262763.0      50022.0           20467.0        1265.0)

# %%
# Weekly Max/Min
weekly_max_tests = weekly_df['Daily Tests'].max()
weekly_min_tests = weekly_df['Daily Tests'].min()

# Monthly Max/Min
monthly_max_tests = monthly_df['Daily Tests'].max()
monthly_min_tests = monthly_df['Daily Tests'].min()

weekly_max_tests, weekly_min_tests, monthly_max_tests, monthly_min_tests
# Out:
# (70191.0, 0.0, 262763.0, 0.0)

# %%
#q4


population_million = 220


df_filled['Date'] = pd.to_datetime(df_filled['Date'])

# Calculate Per Thousand and Per Million stats
df_filled['Tests per Thousand'] = (df_filled['Daily Tests'] / population_million) / 1000
df_filled['Cases per Thousand'] = (df_filled['Daily Cases'] / population_million) / 1000
df_filled['Recoveries per Thousand'] = (df_filled['Daily Recoveries'] / population_million) / 1000
df_filled['Deaths per Thousand'] = (df_filled['Daily Deaths'] / population_million) / 1000

df_filled['Tests per Million'] = (df_filled['Daily Tests'] / population_million) * 1
df_filled['Cases per Million'] = (df_filled['Daily Cases'] / population_million) * 1
df_filled['Recoveries per Million'] = (df_filled['Daily Recoveries'] / population_million) * 1
df_filled['Deaths per Million'] = (df_filled['Daily Deaths'] / population_million) * 1

# Group by Month and aggregate the data
monthly_data = df_filled.groupby(df_filled['Date'].dt.to_period('M')).agg({
    'Daily Tests': 'sum',
    'Daily Cases': 'sum',
    'Tests per Thousand': 'sum',
    'Cases per Thousand': 'sum',
    'Tests per Million': 'sum',
    'Cases per Million': 'sum',
}).reset_index()

# Rename the 'Date' column to 'Month' and format it
monthly_data['Month'] = monthly_data['Date'].dt.strftime('%B')
monthly_data = monthly_data.drop(columns=['Date'])

# Calculate the positive rate
monthly_data['Positive Rate'] = (monthly_data['Daily Cases'] / monthly_data['Daily Tests']) * 100

# Rearrange the columns to match the format in the image
monthly_data = monthly_data[['Month', 'Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate']]

# Display the DataFrame as a formatted table
styled_table = monthly_data.style.set_table_styles(
    [{'selector': 'thead th', 'props': [('background-color', '#2d4154'), ('color', 'white')]}]
).background_gradient(cmap='Blues', subset=['Daily Tests', 'Daily Cases', 'Tests per Thousand', 'Cases per Thousand', 'Tests per Million', 'Cases per Million', 'Positive Rate'])

# Show the styled DataFrame
styled_table
# Out:
# <style type="text/css">
# #T_974ae thead th {
#   background-color: #2d4154;
#   color: white;
# }
# #T_974ae_row0_col1, #T_974ae_row0_col2, #T_974ae_row0_col3, #T_974ae_row0_col4, #T_974ae_row0_col5, #T_974ae_row0_col6, #T_974ae_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_974ae_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_974ae_row1_col1, #T_974ae_row1_col3, #T_974ae_row1_col5 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_974ae_row1_col2, #T_974ae_row1_col4, #T_974ae_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_974ae_row1_col7 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_974ae_row2_col1, #T_974ae_row2_col3, #T_974ae_row2_col5 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_974ae_row2_col2, #T_974ae_row2_col4, #T_974ae_row2_col6 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_974ae_row2_col7 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_974ae_row3_col1, #T_974ae_row3_col3, #T_974ae_row3_col5 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_974ae_row3_col2, #T_974ae_row3_col4, #T_974ae_row3_col6 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_974ae_row3_col7 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_974ae_row4_col1, #T_974ae_row4_col2, #T_974ae_row4_col3, #T_974ae_row4_col4, #T_974ae_row4_col5, #T_974ae_row4_col6, #T_974ae_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_974ae_row5_col1, #T_974ae_row5_col3, #T_974ae_row5_col5 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_974ae_row5_col2, #T_974ae_row5_col4, #T_974ae_row5_col6 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_974ae_row5_col7 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_974ae_row6_col1, #T_974ae_row6_col3, #T_974ae_row6_col5 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_974ae_row6_col2, #T_974ae_row6_col4, #T_974ae_row6_col6 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_974ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_974ae_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_974ae_level0_col1" class="col_heading level0 col1" >Daily Tests</th>
#       <th id="T_974ae_level0_col2" class="col_heading level0 col2" >Daily Cases</th>
#       <th id="T_974ae_level0_col3" class="col_heading level0 col3" >Tests per Thousand</th>
#       <th id="T_974ae_level0_col4" class="col_heading level0 col4" >Cases per Thousand</th>
#       <th id="T_974ae_level0_col5" class="col_heading level0 col5" >Tests per Million</th>
#       <th id="T_974ae_level0_col6" class="col_heading level0 col6" >Cases per Million</th>
#       <th id="T_974ae_level0_col7" class="col_heading level0 col7" >Positive Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_974ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_974ae_row0_col0" class="data row0 col0" >February</td>
#       <td id="T_974ae_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_974ae_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_974ae_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_974ae_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_974ae_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_974ae_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_974ae_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_974ae_row1_col0" class="data row1 col0" >March</td>
#       <td id="T_974ae_row1_col1" class="data row1 col1" >10310.000000</td>
#       <td id="T_974ae_row1_col2" class="data row1 col2" >708.000000</td>
#       <td id="T_974ae_row1_col3" class="data row1 col3" >0.046864</td>
#       <td id="T_974ae_row1_col4" class="data row1 col4" >0.003218</td>
#       <td id="T_974ae_row1_col5" class="data row1 col5" >46.863636</td>
#       <td id="T_974ae_row1_col6" class="data row1 col6" >3.218182</td>
#       <td id="T_974ae_row1_col7" class="data row1 col7" >6.867119</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_974ae_row2_col0" class="data row2 col0" >April</td>
#       <td id="T_974ae_row2_col1" class="data row2 col1" >58931.000000</td>
#       <td id="T_974ae_row2_col2" class="data row2 col2" >5632.000000</td>
#       <td id="T_974ae_row2_col3" class="data row2 col3" >0.267868</td>
#       <td id="T_974ae_row2_col4" class="data row2 col4" >0.025600</td>
#       <td id="T_974ae_row2_col5" class="data row2 col5" >267.868182</td>
#       <td id="T_974ae_row2_col6" class="data row2 col6" >25.600000</td>
#       <td id="T_974ae_row2_col7" class="data row2 col7" >9.556939</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_974ae_row3_col0" class="data row3 col0" >May</td>
#       <td id="T_974ae_row3_col1" class="data row3 col1" >153954.000000</td>
#       <td id="T_974ae_row3_col2" class="data row3 col2" >19900.000000</td>
#       <td id="T_974ae_row3_col3" class="data row3 col3" >0.699791</td>
#       <td id="T_974ae_row3_col4" class="data row3 col4" >0.090455</td>
#       <td id="T_974ae_row3_col5" class="data row3 col5" >699.790909</td>
#       <td id="T_974ae_row3_col6" class="data row3 col6" >90.454545</td>
#       <td id="T_974ae_row3_col7" class="data row3 col7" >12.925939</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_974ae_row4_col0" class="data row4 col0" >June</td>
#       <td id="T_974ae_row4_col1" class="data row4 col1" >262763.000000</td>
#       <td id="T_974ae_row4_col2" class="data row4 col2" >50022.000000</td>
#       <td id="T_974ae_row4_col3" class="data row4 col3" >1.194377</td>
#       <td id="T_974ae_row4_col4" class="data row4 col4" >0.227373</td>
#       <td id="T_974ae_row4_col5" class="data row4 col5" >1194.377273</td>
#       <td id="T_974ae_row4_col6" class="data row4 col6" >227.372727</td>
#       <td id="T_974ae_row4_col7" class="data row4 col7" >19.036927</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_974ae_row5_col0" class="data row5 col0" >July</td>
#       <td id="T_974ae_row5_col1" class="data row5 col1" >231708.000000</td>
#       <td id="T_974ae_row5_col2" class="data row5 col2" >16795.000000</td>
#       <td id="T_974ae_row5_col3" class="data row5 col3" >1.053218</td>
#       <td id="T_974ae_row5_col4" class="data row5 col4" >0.076341</td>
#       <td id="T_974ae_row5_col5" class="data row5 col5" >1053.218182</td>
#       <td id="T_974ae_row5_col6" class="data row5 col6" >76.340909</td>
#       <td id="T_974ae_row5_col7" class="data row5 col7" >7.248347</td>
#     </tr>
#     <tr>
#       <th id="T_974ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_974ae_row6_col0" class="data row6 col0" >August</td>
#       <td id="T_974ae_row6_col1" class="data row6 col1" >224520.000000</td>
#       <td id="T_974ae_row6_col2" class="data row6 col2" >3775.000000</td>
#       <td id="T_974ae_row6_col3" class="data row6 col3" >1.020545</td>
#       <td id="T_974ae_row6_col4" class="data row6 col4" >0.017159</td>
#       <td id="T_974ae_row6_col5" class="data row6 col5" >1020.545455</td>
#       <td id="T_974ae_row6_col6" class="data row6 col6" >17.159091</td>
#       <td id="T_974ae_row6_col7" class="data row6 col7" >1.681365</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Q5

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Prepare data for ML models
X = df_filled[['Daily Tests']]  # Feature (you can choose other features as well)
cases = df_filled['Daily Cases']  # Target for cases
deaths = df_filled['Daily Deaths']  # Target for deaths

# Drop rows with missing values in X, y_cases, or y_deaths
df_clean = df_filled.dropna(subset=['Daily Tests', 'Daily Cases', 'Daily Deaths'])
X_clean = df_clean[['Daily Tests']]
cases_clean = df_clean['Daily Cases']
deaths_clean = df_clean['Daily Deaths']

# Split the data into training and testing sets
X_train, X_test, y_cases_train, y_cases_test = train_test_split(X_clean, cases_clean, test_size=0.2, random_state=42)
_, _, y_deaths_train, y_deaths_test = train_test_split(X_clean, deaths_clean, test_size=0.2, random_state=42)

# Linear Regression Model for Daily Cases
model = LinearRegression()
model.fit(X_train, y_cases_train)
cases_predictions = model.predict(X_test)


# Display the results
print(f"Cases: {cases_predictions}")
# Out:
# Cases: [1066.73723819  743.18373484  -35.6961762   -35.6961762   433.71706554
#  1104.22818235  154.08786364  529.77374497  -35.6961762   788.99367549
#   130.68375353  894.8113108   103.39744505  552.29049546  210.65703975
#   327.34483047 1094.35630652  358.51333731   81.10253447  821.82598163
#   522.23118816  590.00327954  884.05207535  -35.6961762   257.9089398
#   964.69088129  -35.6961762   865.41752322   16.10344192  670.97484534
#   538.86918113  -35.6961762   742.29637522  593.21995818  565.9336497
#   972.34435806  372.93293122  813.839745  ]

# %%
# Random Forest Model for Daily Deaths
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_deaths_train)
deaths_predictions = rf_model.predict(X_test)

print(f" Deaths: {deaths_predictions}")
# Out:
#  Deaths: [ 6.61        2.17        0.128674    0.128674    7.99       52.72
#   3.09       15.99        0.128674    3.01        1.11       44.29
#   0.77       20.95333333  1.57742857 11.62       63.63        7.68
#   0.99       35.02       12.98        7.94       31.32        0.128674
#   5.71       50.91        0.128674   26.14        0.13        8.92
#  13.54        0.128674    2.4         6.23        8.69333333 41.53
#   7.19       25.1       ]
